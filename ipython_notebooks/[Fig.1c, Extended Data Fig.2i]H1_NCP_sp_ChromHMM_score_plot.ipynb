# %% [markdown]
# plot chromHMM

# %%
# python modules
import sys
import copy
import re
import random
import glob
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy
from scipy import stats

# %%
# custom modules
sys.path.append('/Users/sangwoopark/Projects/condense-seq/postpro_scripts')
import graphics_edit as graphics
import load_file_edit as load_file
import Interval_dict
import statis_edit as statis

# %%
# matplotlib setting
# %matplotlib inline
mpl.rcParams["figure.facecolor"] = "white"
mpl.rcParams["axes.facecolor"] = "white"
mpl.rcParams["savefig.facecolor"] = "white"

# %%
### parameters
cell_org = {'H1':'human',
            'GM':'human',
            'mCD8T:WT':'mouse',
            'mCD8T:DFMO':'mouse',
            'mCD8T:ODCKO':'mouse'}

cell_chrnames = {'H1':['chr%s' % (i) for i in range(1, 23)] + ['chrX', 'chrY'],
                 'GM':['chr%s' % (i) for i in range(1, 23)] + ['chrX'],
                 'mCD8T:WT':['chr%s' % (i) for i in range(1, 20)] + ['chrX'],
                 'mCD8T:DFMO':['chr%s' % (i) for i in range(1, 20)] + ['chrX'],
                 'mCD8T:ODCKO':['chr%s' % (i) for i in range(1, 20)] + ['chrX']}

# %%
agent_fullname = {'sp':'Spermine(4+)',
                  'spd':'Spermidine(3+)',
                  'CoH':'Cobalt Hexammine(3+)',
                  'PEG':'PEG 8000',
                  'HP1a':'HP1$\\alpha$',
                  'HP1bSUV':'HP1$\\beta$+tSUV',
                  'LKH':'Linker histone1',
                  'Ki67':'Ki67',
                  'FUS':'FUS',
                  'Mg':'Magnesium',
                  'Ca':'Calcium'}

# %%
## for H1
H1_name_dict = {"E1":"Polycomb repressed",
                "E2":"Poised promoter",
                "E3":"Weak promoter",
                "E4":"Strong enhancer",
                "E5":"Active promoter",
                "E6":"Weak enhancer",
                "E7":"Quiescence1",
                "E8":"Quiescence2",
                "E9":"Heterochromatin",
                "E10":"Tx elongation",
                "E11":"Weak Tx",
                "E12":"Insulator"}

# state for H1
H1_states = ["Active promoter", "Weak promoter", "Poised promoter", "Strong enhancer", "Weak enhancer", "Tx elongation", "Weak Tx", "Insulator", "Polycomb repressed", "Heterochromatin", "Quiescence1", "Quiescence2"]

H1_HMM_fname = "H1_12_segments.bed"

# %%
# for GM12878
GM_name_dict = {"E1":"Polycomb repressed",
                "E2":"Quiescence",
                "E3":"Heterochromatin",
                "E4":"Weak Tx",
                "E5":"Tx elongation",
                "E6":"Weak enhancer",
                "E7":"Active enhancer",
                "E8":"Strong enhancer",
                "E9":"Active promoter",
                "E10":"Weak promoter",
                "E11":"Poised promoter",
                "E12":"Insulator"}

# state for GM
GM_states = ["Active promoter", "Weak promoter", "Poised promoter", "Strong enhancer", "Active enhancer", "Weak enhancer", "Tx elongation", "Weak Tx", "Insulator", "Polycomb repressed", "Heterochromatin", "Quiescence"]

GM_HMM_fname = "GM12878_12_segments.bed"

# %%
# for mouse CD8 T cell
mCD8T_name_dict = {"E1":"Weak Tx",
                   "E2":"Tx elongation",
                   "E3":"Weak enhancer2",
                   "E4":"Strong enhancer2",
                   "E5":"Strong enhancer1",
                   "E6":"Weak enhancer1",
                   "E7":"Active promoter",
                   "E8":"Poised promoter",
                   "E9":"Polycomb repressed1",
                   "E10":"Polycomb repressed2",
                   "E11":"Quiescence",
                   "E12":"Heterochromatin"}

# state for mouse CD8 T cell
mCD8T_states = ["Active promoter", "Poised promoter", "Strong enhancer1", "Strong enhancer2", "Weak enhancer1", "Weak enhancer2", "Tx elongation", "Weak Tx", "Polycomb repressed1", "Polycomb repressed2", "Heterochromatin", "Quiescence"]

mCD8T_HMM_fname = "Mouse CD8 T cell (invitro activated)_12_segments.bed"

# %%
# data path
#path = './data/'
path = '/Users/sangwoopark/jhu_rockfish/2024_01_05_GEO/processed_files/'
chromHMM_path = '/Users/sangwoopark/jhu_rockfish/chromHMM_data/'

# %%
# chromHMM data set
cell_chromHMM = {'H1':[H1_HMM_fname, H1_name_dict, H1_states],
                 'GM':[GM_HMM_fname, GM_name_dict, GM_states],
                 'mCD8T':[mCD8T_HMM_fname, mCD8T_name_dict, mCD8T_states]}

# %%
### set target cell
cell = 'H1'

# %%
### set target chromosomesx
#chr_choices = cell_chromHMM['H1']
chr_choices = ['chr1']

# %%
### load gtab file
gtab_path = '/Users/sangwoopark/jhu_rockfish/2024_01_05_GEO/processed_files/'

dinfo_dkey = {'H1_NCP_sp_1rep_deep_chr1_score.gtab.gz':
              {'H1_NCP_sp_8_1rep_deep': ('H1', 'score', 8)}}

dkey_chr_ID_value = load_file.read_gtab_batch(dinfo_dkey,
                                              data_path=gtab_path,
                                              chr_choices=chr_choices,
                                              by_chr=True)
# Out:
# loading H1_NCP_sp_1rep_deep_chr1_score.gtab.gz
# Done

# %%
### loading the chromHMM data
chromHMM_path = '/Users/sangwoopark/jhu_rockfish/chromHMM_data/'

HMM_fname, name_dict, states = cell_chromHMM[cell]
chr_state_intervals = load_file.read_chromHMM(chromHMM_path + HMM_fname,
                                              state_name=name_dict,
                                              chr_choices=chr_choices)

# %%
### make chromHMM interval dictionary
chr_state_dict = {}
for chr in chr_choices:
    state_intervals = chr_state_intervals[chr]
    dID_interval = {}
    for state in state_intervals:        
        intervals = state_intervals[state]
        for i in range(len(intervals)):
            dID = state + ':' + str(i)
            assert dID not in dID_interval
            dID_interval[dID] = intervals[i]

    state_dict = Interval_dict.double_hash(dID_interval)
    chr_state_dict[chr] = state_dict
# Out:
# hash fucntion is built

# %%
### categorize by chromHMM
dkey_state_IDs = {}
for dkey in dkey_chr_ID_value:
    chr_ID_value = dkey_chr_ID_value[dkey]
    state_IDs = {}
    for chr in chr_ID_value:
        try:
            ID_interval = {ID:(ID[1], ID[2]) for ID in chr_ID_value[chr]}        
            state_IDs_temp = statis.categorize_bin(chr_state_intervals[chr],
                                                   ID_interval,
                                                   hash_func=chr_state_dict[chr])
        except:
            ID_pos = {ID:ID[1] for ID in chr_ID_value[chr]}        
            state_IDs_temp = statis.categorize(chr_state_intervals[chr],
                                               ID_pos,
                                               hash_func=chr_state_dict[chr])

        for state in state_IDs_temp:
            if state not in state_IDs:
                state_IDs[state] = []
            state_IDs[state] +=state_IDs_temp[state]
    dkey_state_IDs[dkey] = state_IDs

# %%
### get values for each state
dkey_state_values = {}
for dkey in dkey_state_IDs:    
    state_IDs = dkey_state_IDs[dkey]
    chr_ID_value = dkey_chr_ID_value[dkey]
    
    state_values = {}
    for state, IDs in state_IDs.items():
        values = [chr_ID_value[ID[0]][ID] for ID in IDs]
        if state not in state_values:
            state_values[state] = []
        state_values[state] += values

    dkey_state_values[dkey] = state_values

# %%
### plot the chromHMM [Fig.1c]
for dkey in dkey_state_values:
    state_values = dkey_state_values[dkey]
    
    graphics.plot_boxplot (state_values,
                           keys = states,
                           ylabel='Condensability (A.U.)',
                           title='H1-hESC Chromosome1',
                           rotation=75,
                           fig_width=5,
                           fig_height=4,
                           ylabel_fontsize=13,
                           title_fontsize=15,
                           xticklabel_fontsize=12,
                           save_path='./data/',
                           save=True,
                           note='H1_NCP_sp_score')

# %%
### statistical testing for comparing two states
state_values = dkey_state_values[('H1', 'score', 8)]
pair_pvalue = statis.get_pvalue_pair (state_values,
                                      keys = states)
for i in range(len(states)-1):
    for j in range(i+1, len(states)):
        state1, state2 = states[i], states[j]
        print state1, state2
        print pair_pvalue[state1][state2]
        print
# Out:
# Active promoter Weak promoter
# 0.0
#
# Active promoter Poised promoter
# 0.0
#
# Active promoter Strong enhancer
# 0.0
#
# Active promoter Weak enhancer
# 0.0
#
# Active promoter Tx elongation
# 0.0
#
# Active promoter Weak Tx
# 0.0
#
# Active promoter Insulator
# 0.0
#
# Active promoter Polycomb repressed
# 0.0
#
# Active promoter Heterochromatin
# 0.0
#
# Active promoter Quiescence1
# 0.0
#
# Active promoter Quiescence2
# 0.0
#
# Weak promoter Poised promoter
# 1.0993846115914289e-41
#
# Weak promoter Strong enhancer
# 0.04207775547398124
#
# Weak promoter Weak enhancer
# 0.0
#
# Weak promoter Tx elongation
# 0.0
#
# Weak promoter Weak Tx
# 0.0
#
# Weak promoter Insulator
# 0.0
#
# Weak promoter Polycomb repressed
# 0.0
#
# Weak promoter Heterochromatin
# 0.0
#
# Weak promoter Quiescence1
# 0.0
#
# Weak promoter Quiescence2
# 0.0
#
# Poised promoter Strong enhancer
# 8.81743127488334e-34
#
# Poised promoter Weak enhancer
# 0.0
#
# Poised promoter Tx elongation
# 0.0
#
# Poised promoter Weak Tx
# 0.0
#
# Poised promoter Insulator
# 0.0
#
# Poised promoter Polycomb repressed
# 0.0
#
# Poised promoter Heterochromatin
# 0.0
#
# Poised promoter Quiescence1
# 0.0
#
# Poised promoter Quiescence2
# 0.0
#
# Strong enhancer Weak enhancer
# 0.0
#
# Strong enhancer Tx elongation
# 0.0
#
# Strong enhancer Weak Tx
# 0.0
#
# Strong enhancer Insulator
# 0.0
#
# Strong enhancer Polycomb repressed
# 0.0
#
# Strong enhancer Heterochromatin
# 0.0
#
# Strong enhancer Quiescence1
# 0.0
#
# Strong enhancer Quiescence2
# 0.0
#
# Weak enhancer Tx elongation
# 0.0
#
# Weak enhancer Weak Tx
# 0.0
#
# Weak enhancer Insulator
# 0.0
#
# Weak enhancer Polycomb repressed
# 0.0
#
# Weak enhancer Heterochromatin
# 0.0
#
# Weak enhancer Quiescence1
# 0.0
#
# Weak enhancer Quiescence2
# 0.0
#
# Tx elongation Weak Tx
# 0.0
#
# Tx elongation Insulator
# 0.0
#
# Tx elongation Polycomb repressed
# 0.0
#
# Tx elongation Heterochromatin
# 0.0
#
# Tx elongation Quiescence1
# 0.0
#
# Tx elongation Quiescence2
# 0.0
#
# Weak Tx Insulator
# 0.0
#
# Weak Tx Polycomb repressed
# 0.0
#
# Weak Tx Heterochromatin
# 0.0
#
# Weak Tx Quiescence1
# 0.0
#
# Weak Tx Quiescence2
# 0.0
#
# Insulator Polycomb repressed
# 5.291314994609919e-208
#
# Insulator Heterochromatin
# 0.0
#
# Insulator Quiescence1
# 0.0
#
# Insulator Quiescence2
# 0.0
#
# Polycomb repressed Heterochromatin
# 0.0
#
# Polycomb repressed Quiescence1
# 2.3288734939462818e-33
#
# Polycomb repressed Quiescence2
# 0.0
#
# Heterochromatin Quiescence1
# 0.0
#
# Heterochromatin Quiescence2
# 0.0
#
# Quiescence1 Quiescence2
# 0.0

# %%
### plot p-value for comparing two states
graphics.plot_matrix (pair_pvalue,
                      keys=states,
                      log_scale='-log10',
                      dummy=10**-10,
                      rotation=45,
                      cmap='Reds',
                      vmin=0,
                      vmax=5,
                      fig_width=5,
                      fig_height=5,
                      cbar=True,
                      cbar_label='p-value',
                      text=True,
                      text_color='w',
                      text_fontsize=5,
                      decimal_pt=1,
                      save_path='./data/',
                      save=True,
                      note='H1_NCP_sp_pvalue_ChromHMM')

# %%
### compute the Conhen's d
pair_CohenD =  statis.get_CohenD_pair (state_values,
                                       keys=states)

# %%
### plot Cohen's d for comparing two states
graphics.plot_matrix (pair_CohenD,
                      keys=states,
                      rotation=45,
                      cmap='Reds',
                      fig_width=5,
                      fig_height=5,
                      cbar=True,
                      cbar_label="Cohens' d",
                      text=True,
                      text_color='k',
                      text_fontsize=7,
                      decimal_pt=1,
                      save_path='./data/',
                      save=True,
                      note='H1_NCP_sp_CohenD_ChromHMM')

# %%
### plot Cohen'sd and p-value for comparing two states [Extended Data Fig.2i]
graphics.plot_matrix_dual (pair_CohenD,
                           pair_pvalue,
                           keys=states,
                           log_scale2='-log10',
                           dummy2=10**-10,
                           rotation=45,
                           cmap1='Reds',
                           cmap2='Blues',
                           vmin2=0,
                           vmax2=5,
                           fig_width=6,
                           fig_height=6,
                           cbar1=True,
                           cbar_label1="Cohen's d",
                           cbar2=True,
                           cbar_label2='p-value',
                           text1=True,
                           text_color1='tab:blue',
                           text_fontsize1=7,
                           decimal_pt1=1,
                           text2=True,
                           text_color2='tab:red',
                           text_fontsize2=6,
                           decimal_pt2=1,
                           save_path='./data/',
                           save=True,
                           note='H1_NCP_sp_CohenD_pavlue_ChromHMM')
