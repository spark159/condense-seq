# %% [markdown]
# Get pair-wise correlations between replicates over titrations

# %%
# python modules
import sys
import copy
import re
import random
import glob
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy
from scipy import stats

# %%
# custom modules
sys.path.append('/Users/sangwoopark/Projects/condense-seq/postpro_scripts')
import graphics_edit as graphics
import load_file_edit as load_file
import Interval_dict
import statis_edit as statis

# %%
# matplotlib setting
# %matplotlib inline
mpl.rcParams["figure.facecolor"] = "white"
mpl.rcParams["axes.facecolor"] = "white"
mpl.rcParams["savefig.facecolor"] = "white"

# %%
### parameters
cell_org = {'H1':'human',
            'GM':'human',
            'mCD8T:WT':'mouse',
            'mCD8T:DFMO':'mouse',
            'mCD8T:ODCKO':'mouse'}

cell_chrnames = {'H1':['chr%s' % (i) for i in range(1, 23)] + ['chrX', 'chrY'],
                 'GM':['chr%s' % (i) for i in range(1, 23)] + ['chrX'],
                 'mCD8T:WT':['chr%s' % (i) for i in range(1, 20)] + ['chrX'],
                 'mCD8T:DFMO':['chr%s' % (i) for i in range(1, 20)] + ['chrX'],
                 'mCD8T:ODCKO':['chr%s' % (i) for i in range(1, 20)] + ['chrX']}

agent_fullname = {'sp':'Spermine(4+)',
                  'spd':'Spermidine(3+)',
                  'CoH':'Cobalt Hexammine(3+)',
                  'PEG':'PEG 8000',
                  'HP1a':'HP1$\\alpha$',
                  'HP1bSUV':'HP1$\\beta$+tSUV',
                  'LKH':'Linker histone1',
                  'Ki67':'Ki67',
                  'FUS':'FUS',
                  'Mg':'Magnesium',
                  'Ca':'Calcium'}

agent_charge = {'sp':'4+',
                'spd':'3+',
                'CoH':'3+',
                'PEG':'',
                'Ca':'2+',
                'Mg':'2+',
                'HP1a':'',
                'HP1bSUV':'',
                'LKH':'',
                'Ki67':'',
                'FUS':''}

# %%
### load gtab files
gtab_path = "/Users/sangwoopark/jhu_rockfish/2024_01_05_GEO/processed_files/"
dinfo_dkey = {'H1_NCP_sp_1rep_deep_1kb_score.gtab.gz':
              {'H1_NCP_sp_8_1rep_deep':(1, 'H1', 'NCP', 'sp', 8)},
              'H1_NCP_sp_2rep_deep_1kb_score.gtab.gz':
              {'H1_NCP_sp_8_2rep_deep':(2, 'H1', 'NCP', 'sp', 8)},
              'H1_NCP_HP1a_1rep_deep_1kb_score.gtab.gz':
              {'H1_NCP_HP1a_3_1rep_deep':(1, 'H1', 'NCP', 'HP1a', 3)},
              'H1_NCP_HP1a_2rep_deep_1kb_score.gtab.gz':
              {'H1_NCP_HP1a_3_2rep_deep':(2, 'H1', 'NCP', 'HP1a', 3)},
              'GM_NCP_sp_1rep_deep_1kb_score.gtab.gz':
              {'GM_NCP_sp_8_1rep_deep':(1, 'GM', 'NCP', 'sp', 8)},
              'GM_NCP_sp_2rep_deep_1kb_score.gtab.gz':
              {'GM_NCP_sp_8_2rep_deep':(2, 'GM', 'NCP', 'sp', 8)}
              }

dkey_ID_score = load_file.read_gtab_batch (dinfo_dkey,
                                           data_path=gtab_path)

dkey_list = [(1, 'H1', 'NCP', 'sp', 8),
             (2, 'H1', 'NCP', 'sp', 8),
             (1, 'H1', 'NCP', 'HP1a', 3),
             (2, 'H1', 'NCP', 'HP1a', 3),
             (1, 'GM', 'NCP', 'sp', 8),
             (2, 'GM', 'NCP', 'sp', 8)]
# Out:
# loading H1_NCP_sp_2rep_deep_1kb_score.gtab.gz
# loading H1_NCP_sp_1rep_deep_1kb_score.gtab.gz
# loading H1_NCP_HP1a_2rep_deep_1kb_score.gtab.gz
# loading GM_NCP_sp_2rep_deep_1kb_score.gtab.gz
# loading GM_NCP_sp_1rep_deep_1kb_score.gtab.gz
# loading H1_NCP_HP1a_1rep_deep_1kb_score.gtab.gz
# Done

# %%
### get common IDs
ID_list = set([])
for i in range(len(dkey_list)):
    dkey = dkey_list[i]
    if i == 0:
        ID_list |= set(dkey_ID_score[dkey].keys())
        continue
    ID_list &= set(dkey_ID_score[dkey].keys())
ID_list = sorted(list(ID_list))

# %%
### reorganize data and make labels
dkey_label = {}
dkey_data = {}
for dkey in dkey_list:
    rep, cell, sample, agent, tnum = dkey
    label = '%s %s$^{%s}$\n%d-rep' % (cell, agent, agent_charge[agent], rep)
    dkey_label[dkey] = label
    data = [dkey_ID_score[dkey][ID] for ID in ID_list]
    dkey_data[dkey] = data

# %%
# plot correlation matrix between experiment
graphics.plot_corr_matrix(dkey_data,
                          dkey_label,
                          ids = dkey_list,
                          scatter_style='density',
                          fig_scale=0.5,
                          cbar=True,
                          title = "Correlation betwen experiments (1 kb bin)",
                          note='human_1kb_deep')
